# %%
#@markdown # Подключаем гугл дикс и устанавливаем рабочий путь 
from google.colab import drive
drive.mount('/content/gdrive')

working_dir = '/content/gdrive/Shareddrives/ML/AIIJC/working_dir' #@param{type:"string"}

# %%
pip install ffmpeg-python

# %%
# если не сломо

import ffmpeg

video = ffmpeg.input(f'working_dir/video.mp4')
audio = ffmpeg.input(f'working_dir/audio.wav')
out = ffmpeg.output(video, audio, f"working_dir/combined.mp4", vcodec='copy', acodec='aac', strict='experimental')
out.run()

# %%
# если сломо

import ffmpeg

video = ffmpeg.input(f'working_dir/video.mp4-slomo.mp4')
audio = ffmpeg.input(f'working_dir/audio.wav')
out = ffmpeg.output(video, audio, f"working_dir/combined+slomo.mp4", vcodec='copy', acodec='aac', strict='experimental')
out.run()
